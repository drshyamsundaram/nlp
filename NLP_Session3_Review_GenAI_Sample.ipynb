# %% [markdown]
# <a href="https://colab.research.google.com/github/drshyamsundaram/nlp/blob/main/NLP_Session3_Review_GenAI_Sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #NLP_Session3_Review_GenAI_Sample
# drshyamsundaramindia@gmail.com
#
# The purpose of this code example is to use GenAI for generating say an comprehensive sentimemnt analysis/ NLP code for analysis.
#
# This code is generated mostly by OpenAI - Chatgpt the following prompt.
#
#
# ##Prompt 1:
# Use the following review [Top positive review
# All positive reviews›
# 	venkat sai chowdary
# 5.0 out of 5 starsBEAST IS HERE....🥳🥳
# Reviewed in India on 24 May 2021
# What can I say!
# SIMPLY SPECTACULAR.
# PUBG - smooth +90 FPS
# Smashing all the bench marks by some margin (140%~~)
# 4 SPEAKERS are like home theatre.
# Battery backup is excellent
# Could have been better than 20 wts charger
# ] and provide a python code with library installations plus documentation that generates a resultsJSON [number of characters, number of n-grams, sentiment subjectivity, sentiment polarity, sentence-wise sentiment subjectivity, sentence-wise sentiment polarity, top 30 wordcloud]
# ##Prompt 2
# Code for nltk core corpus download

# %%
# !pip install nltk
# !pip install textblob
# !pip install wordcloud
# !pip install matplotlib

# %%
import nltk
# Download NLTK data
nltk.download('popular')
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gazetteers.zip.
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/genesis.zip.
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/gutenberg.zip.
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/inaugural.zip.
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/movie_reviews.zip.
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/names.zip.
# ...

# %%
import nltk
from textblob import TextBlob
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Define the review text
review_text = """
What can I say!
SIMPLY SPECTACULAR.
PUBG - smooth +90 FPS
Smashing all the benchmarks by some margin (140%~~)
4 SPEAKERS are like home theatre.
Battery backup is excellent
Could have been better than 20 wts charger
"""

# Calculate the number of characters
num_characters = len(review_text)

# Calculate n-grams
from nltk.util import ngrams
n = 3  # You can change n to 1, 2, or 3 for different n-grams
tokens = nltk.word_tokenize(review_text)
n_grams = list(ngrams(tokens, n))

# Calculate sentiment analysis
analysis = TextBlob(review_text)
sentiment_subjectivity = analysis.sentiment.subjectivity
sentiment_polarity = analysis.sentiment.polarity

# Calculate sentence-wise sentiment
sentences = nltk.sent_tokenize(review_text)
sentence_sentiments = []

for sentence in sentences:
    sentence_blob = TextBlob(sentence)
    sentence_subjectivity = sentence_blob.sentiment.subjectivity
    sentence_polarity = sentence_blob.sentiment.polarity
    sentence_sentiments.append({
        "Sentence": sentence,
        "Subjectivity": sentence_subjectivity,
        "Polarity": sentence_polarity
    })

# Generate a word cloud
wordcloud = WordCloud(width=800, height=400, max_words=30, background_color='white').generate(review_text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.show()

# Create the results JSON
results_json = {
    "Number of characters": num_characters,
    "Number of n-grams": len(n_grams),
    "Sentiment subjectivity": sentiment_subjectivity,
    "Sentiment polarity": sentiment_polarity,
    "Sentence-wise sentiment": sentence_sentiments,
    "Top 30 wordcloud": wordcloud.words_
}

# Print the results JSON
import json
print(json.dumps(results_json, indent=2))
# Out:
# {
#   "Number of characters": 216,
#   "Number of n-grams": 42,
#   "Sentiment subjectivity": 0.725,
#   "Sentiment polarity": 0.625,
#   "Sentence-wise sentiment": [
#     {
#       "Sentence": "\nWhat can I say!",
#       "Subjectivity": 0.0,
#       "Polarity": 0.0
#     },
#     {
#       "Sentence": "SIMPLY SPECTACULAR.",
#       "Subjectivity": 0.9,
#       "Polarity": 0.6
#     },
#     {
#       "Sentence": "PUBG - smooth +90 FPS\nSmashing all the benchmarks by some margin (140%~~)\n4 SPEAKERS are like home theatre.",
#       "Subjectivity": 0.5,
#       "Polarity": 0.4
#     },
#     {
#       "Sentence": "Battery backup is excellent\nCould have been better than 20 wts charger",
#       "Subjectivity": 0.75,
#       "Polarity": 0.75
#     }
#   ],
#   "Top 30 wordcloud": {
#     "say": 1.0,
#     "SIMPLY": 1.0,
#     "SPECTACULAR": 1.0,
#     "PUBG": 1.0,
#     "smooth": 1.0,
#     "FPS": 1.0,
#     "Smashing": 1.0,
#     "benchmarks": 1.0,
#     "margin": 1.0,
# ...
